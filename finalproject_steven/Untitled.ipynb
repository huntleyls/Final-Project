# %%
import wordsegment #
from wordsegment import load, segment
import csv # pip install python-csv (if not installed)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tldextract 
import matplotlib.pyplot as plt
# !pip install newspaper3k
# Out:
# ...
#      -------------------------------------- 211.1/211.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.4/7.4 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 81.1/81.1 kB 4.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=5c724d28d70c7dc99f74f2ae086f9285a7a64fca27fef05c8d2dfbdc25e86772
#   Stored in directory: c:\users\steven\appdata\local\pip\cache\wheels\94\ad\df\a2a01300cea47d5695f242f7e925a805970106fd9e4b151468
# ...

# %%
benign_domain_df = pd.read_csv("benign_domain_list.csv", header=None)
benign_domain_df = benign_domain_df.rename(columns={0: "domain"}, errors="raise")
malicious_url_df = pd.read_csv("Malicious_URls.csv")
malicious_url_df
# Out:
#                                                      url
# 0                              https://ervashipping.com/
# 1        http://www.gabung-grupmabarcimbrut.duckdns.org/
# 2              http://republik-jancuk.000webhostapp.com/
# 3             https://www.chet-notnkt8-grup.duckdns.org/
# 4      http://veromcertiom.ddns.net/connexion/certico...
# ...                                                  ...
# 10624      http://sites.google.com/site/habbotuttogratis
# 10625       http://www.habbocreditosparati.blogspot.com/
# 10626  http://creditiperhabbogratissicuro100.blogspot...
# 10627  http://mundovirtualhabbo.blogspot.com/2009_01_...
# 10628  http://aijcs.blogspot.com/2005/03/colourful-li...
#
# [10629 rows x 1 columns]

# %%
domainlist = []
tldlist = []
for url in malicious_url_df['url']:
    ext = tldextract.extract(url)
    domain = ext.domain
    tld = ext.suffix
    domainlist.append(domain)
    tldlist.append(tld)
    
malicious_url_df['domain'] = domainlist
malicious_url_df['tld'] = tldlist
malicious_url_df
# Out:
#                                                      url         domain  tld
# 0                              https://ervashipping.com/   ervashipping  com
# 1        http://www.gabung-grupmabarcimbrut.duckdns.org/        duckdns  org
# 2              http://republik-jancuk.000webhostapp.com/  000webhostapp  com
# 3             https://www.chet-notnkt8-grup.duckdns.org/        duckdns  org
# 4      http://veromcertiom.ddns.net/connexion/certico...           ddns  net
# ...                                                  ...            ...  ...
# 10624      http://sites.google.com/site/habbotuttogratis         google  com
# 10625       http://www.habbocreditosparati.blogspot.com/       blogspot  com
# 10626  http://creditiperhabbogratissicuro100.blogspot...       blogspot  com
# 10627  http://mundovirtualhabbo.blogspot.com/2009_01_...       blogspot  com
# 10628  http://aijcs.blogspot.com/2005/03/colourful-li...       blogspot  com
#
# [10629 rows x 3 columns]
